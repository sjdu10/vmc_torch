# %% [markdown]
# TODO:
# 1. If want to use customized QR/SVD in batched version, extra work is needed.
# 2. The resulted fpeps from my SU code is not a flat fTNS, but a sparse one. Need conversion between flat and sparse fTN.
#
# BUGS:
# 1. D!=4, bug in fTS.isel:
#     `IndexError: index 2 is out of bounds for axis 4 with size 2`
# 2. Lx=Ly=D=4, chi=16, bug in vmap amp:
#     `RuntimeError: vmap: It looks like you're calling .item() on a Tensor. We don't support vmap over calling .item() on a Tensor, please try to rewrite what you're doing with other operations. If error is occurring somewhere inside PyTorch internals, please file a bug report.`
# 3. pickle save SU flat fPEPS, when loading the saved skeleton and unpack back to fPEPS, get error:
#     `ValueError: Cannot squeeze flat fermionic index with possible odd parity if array has no ordering `.label` attribute.`
#    workaround: initialize a flat-rfPEPS and set its params to saved params.

# %%
import os
os.environ["OPENBLAS_NUM_THREADS"] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ["OMP_NUM_THREADS"] = '1'
import numpy as np
import quimb as qu
import quimb.tensor as qtn
import time
import symmray as sr

Lx = 4
Ly = 4
nsites = Lx * Ly
D = 6
chi = 2*D
seed = 42
# only the flat backend is compatible with jax.jit
flat = True

peps = sr.networks.PEPS_fermionic_rand(
    "Z2",
    Lx,
    Ly,
    D,
    phys_dim=[
        (0, 0),  # linear index 0 -> charge 0, offset 0
        (1, 1),  # linear index 1 -> charge 1, offset 1
        (1, 0),  # linear index 2 -> charge 1, offset 0
        (0, 1),  # linear index 3 -> charge 0, offset 1
    ],
    subsizes="equal",
    flat=flat,
    seed=seed,
)

# %%
# import os
# os.environ["OPENBLAS_NUM_THREADS"] = "1"
# os.environ["MKL_NUM_THREADS"] = "1"
# os.environ["OMP_NUM_THREADS"] = "1"
# from mpi4py import MPI
# # torch
# import torch


# # quimb
# import autoray as ar
# from vmc_torch.hamiltonian_torch import spinful_Fermi_Hubbard_square_lattice_torch
# from vmc_torch.torch_utils import SVD,QR 
# from vmc_torch.fermion_utils import unpack_ftns
# pwd = '/home/sijingdu/TNVMC/VMC_code/vmc_torch/data'
# # # Register safe SVD and QR functions to torch #NOTE: if want to use customized QR/SVD in batched version, extra work is needed
# # ar.register_function('torch','linalg.svd',SVD.apply)
# # ar.register_function('torch','linalg.qr',QR.apply)


# COMM = MPI.COMM_WORLD
# SIZE = COMM.Get_size()
# RANK = COMM.Get_rank()

# # Hamiltonian parameters
# Lx = int(4)
# Ly = int(4)
# symmetry = 'Z2'
# t = 1.0
# U = 8.0
# N_f = int(Lx*Ly)
# n_fermions_per_spin = (N_f//2, N_f//2)
# H = spinful_Fermi_Hubbard_square_lattice_torch(Lx, Ly, t, U, N_f, pbc=False, n_fermions_per_spin=n_fermions_per_spin)
# graph = H.graph
# # TN parameters
# D = 4
# chi = D
# dtype=torch.float64

# if symmetry == 'U1_Z2':
#     su_skeleton = 'peps_skeleton_U1.pkl'
#     su_params = 'peps_su_params_U1.pkl'
#     symmetry = 'Z2'
# else:
#     su_skeleton = 'peps_skeleton.pkl'
#     su_params = 'peps_su_params.pkl'
    
# # Load PEPS
# params_path = pwd+f"/{Lx}x{Ly}/t={t}_U={U}/N={N_f}/{symmetry}/D={D}/{su_params}"
# skeleton_path = pwd+f"/{Lx}x{Ly}/t={t}_U={U}/N={N_f}/{symmetry}/D={D}/{su_skeleton}"
# fpeps = unpack_ftns(params_path=params_path, skeleton_path=skeleton_path, dtype=dtype, scale=4.0, new_symmray_format=True) # NOTE: fpeps is not a flat fTNS, but a sparse one

# %%
# get pytree of initial parameters, and reference tn structure
params, skeleton = qtn.pack(peps)


def amplitude(x, params):
    tn = qtn.unpack(params, skeleton)

    fx = 2 * x[::2] + x[1::2]

    # might need to specify the right site ordering here
    amp = tn.isel({tn.site_ind(site): fx[i] for i, site in enumerate(tn.sites)})

    # amp.contract_boundary_from_ymin_(max_bond=chi, cutoff=0.0, yrange=[0, amp.Ly//2-1])
    # amp.contract_boundary_from_ymax_(max_bond=chi, cutoff=0.0, yrange=[amp.Ly//2, amp.Ly-1])

    return amp.contract()

    # return amp.contract()

    # return tnx.contract_hotrg(
    #     max_bond=chi,
    #     cutoff=0.0,
    #     # these two options make the return value (mantissa, exponent)
    #     # which can avoid issues with small/large values and stability
    #     equalize_norms=1.0,
    #     final_contract_opts=dict(strip_exponent=True),
    # )

# %%
# generate half-filling configs
# batchsize
B = 1024
rng = np.random.default_rng(seed)
xs_u = np.concatenate(
    [
        np.zeros((B, nsites // 2), dtype=np.int32),
        np.ones((B, nsites // 2), dtype=np.int32),
    ],
    axis=1,
)
xs_d = xs_u.copy()
xs_u = rng.permuted(xs_u, axis=1)
xs_d = rng.permuted(xs_d, axis=1)
xs = np.concatenate([xs_u[:, :, None], xs_d[:, :, None]], axis=2).reshape(B, -1)

# %% [markdown]
# First test non eager version:

# %%
amplitude(xs[0], params)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 amplitude(xs[0], params)
#
# Cell In[19], line 11, in amplitude(x, params)
#       8 fx = 2 * x[::2] + x[1::2]
#      10 # might need to specify the right site ordering here
# ---> 11 amp = tn.isel({tn.site_ind(site): fx[i] for i, site in enumerate(tn.sites)})
#      13 # amp.contract_boundary_from_ymin_(max_bond=chi, cutoff=0.0, yrange=[0, amp.Ly//2-1])
#      14 # amp.contract_boundary_from_ymax_(max_bond=chi, cutoff=0.0, yrange=[amp.Ly//2, amp.Ly-1])
#      16 return amp.contract()
#
# File ~/TNVMC/VMC_code/quimb/quimb/tensor/tensor_core.py:8852, in TensorNetwork.isel(self, selectors, inplace)
#    8849 tn = self if inplace else self.copy()
#    8851 for tid in oset_union(map(self.ind_map.__getitem__, selectors)):
# -> 8852     tn.tensor_map[tid].isel_(selectors)
#    8854 return tn
#
# File ~/TNVMC/VMC_code/quimb/quimb/tensor/tensor_core.py:1896, in Tensor.isel(self, selectors, inplace)
#    1892         data_loc.append(sel)
#    1895 if num_project:
# -> 1896     T.modify(
#    1897         apply=lambda x: x[tuple(data_loc)],
#    1898         inds=new_inds,
#    1899         left_inds=None,
#    1900     )
#    1901 return T
#
# File ~/TNVMC/VMC_code/quimb/quimb/tensor/tensor_core.py:1782, in Tensor.modify(self, **kwargs)
#    1779     self._left_inds = None
#    1781 if "apply" in kwargs:
# -> 1782     self._apply_function(kwargs.pop("apply"))
#    1783     self._left_inds = None
#    1785 if "inds" in kwargs:
#
# File ~/TNVMC/VMC_code/quimb/quimb/tensor/tensor_core.py:1758, in Tensor._apply_function(self, fn)
#    1757 def _apply_function(self, fn):
# -> 1758     self._set_data(fn(self.data))
#
# File ~/TNVMC/VMC_code/quimb/quimb/tensor/tensor_core.py:1897, in Tensor.isel.<locals>.<lambda>(x)
#    1892         data_loc.append(sel)
#    1895 if num_project:
#    1896     T.modify(
# -> 1897         apply=lambda x: x[tuple(data_loc)],
#    1898         inds=new_inds,
#    1899         left_inds=None,
#    1900     )
#    1901 return T
#
# File ~/TNVMC/VMC_code/symmray/symmray/abelian_common.py:543, in AbelianCommon.__getitem__(self, item)
#     540         axis = i
#     541         idx = s
# --> 543 return self.isel(axis, idx)
#
# File ~/TNVMC/VMC_code/symmray/symmray/flat/flat_array_common.py:1144, in FlatArrayCommon.isel(self, axis, idx, inplace)
#    1142     axis += self.ndim
#    1143 charge, offset = self.indices[axis].linear_to_charge_and_offset(idx)
# -> 1144 new = self.select_charge(
#    1145     axis, charge, subselect=(offset,), inplace=inplace
#    1146 )
#    1147 # fermionic signs handled in squeeze
#    1148 return new.squeeze(axis, inplace=True)
#
# File ~/TNVMC/VMC_code/symmray/symmray/flat/flat_array_common.py:1055, in FlatArrayCommon.select_charge(self, axis, charge, subselect, inplace)
#    1052         def fn_block(x):
#    1053             return x[selector]
# -> 1055     new._map_blocks(fn_block=fn_block)
#    1057 if new.ndim == 2:
#    1058     # axes are locked to each other -> select both
#    1059     if axis == 0:
#
# File ~/TNVMC/VMC_code/symmray/symmray/flat/flat_fermionic_array.py:305, in FermionicArrayFlat._map_blocks(self, fn_sector, fn_block)
#     304 def _map_blocks(self, fn_sector=None, fn_block=None):
# --> 305     self._map_blocks_abelian(fn_sector=fn_sector, fn_block=fn_block)
#     306     if fn_sector is not None:
#     307         if self._phases is not None:
#     308             # NOTE: leave missing phases, assumed to stay all ones
#
# File ~/TNVMC/VMC_code/symmray/symmray/flat/flat_array_common.py:588, in FlatArrayCommon._map_blocks_abelian(self, fn_sector, fn_block)
#     586     self._sectors = fn_sector(self._sectors)
#     587 if fn_block is not None:
# --> 588     self._blocks = fn_block(self._blocks)
#
# File ~/TNVMC/VMC_code/symmray/symmray/flat/flat_array_common.py:1053, in FlatArrayCommon.select_charge.<locals>.fn_block(x)
#    1052 def fn_block(x):
# -> 1053     return x[selector]
#
# IndexError: index 2 is out of bounds for axis 4 with size 2

# %% [markdown]
# Then test version with torch, gpu tensors:

# %%
import torch

# torch.set_default_device("cuda:0") # GPU
torch.set_default_device("cpu") # CPU

# convert bitstrings and arrays to torch
xs = torch.tensor(xs)
params = qu.tree_map(
    lambda x: torch.tensor(x, dtype=torch.float32),
    params,
)

# %%
# %%timeit
# mantissa, exponent = amplitude(xs[0], params)
# mantissa, exponent

# %% [markdown]
# Then test and warm up torch vmapped version:

# %%
vamp = torch.vmap(
    amplitude,
    # batch on configs, not parameters
    in_dims=(0, None),
)

# %%
# %%time
# warmup time
vamp(xs[:10], params)
# Out:
# CPU times: user 75.9 ms, sys: 4 μs, total: 75.9 ms
# Wall time: 75.3 ms
# tensor([-37643.4141, -42211.4258, -23897.2852,  58300.9844,  -9587.5664,
#         -11176.6641,  25465.9648, -47022.5742, -84887.1875,   3529.0913])

# %%
t0 = time.time()
# final time (to compute full batch)
vamp(xs, params)
t1 = time.time()
print(f"Time taken: {t1 - t0} seconds")
vamp_time = (t1 - t0)/len(xs)
print(f"Time per sample: {vamp_time} seconds")
# Out:
# Time taken: 0.22215819358825684 seconds
# Time per sample: 0.00021695136092603207 seconds

# %%
t0 = time.time()
amplitude(xs[0], params)
t1 = time.time()
print(f"Time taken: {(t1 - t0)} seconds")
amp_time = (t1 - t0)

print(f'speedup: {amp_time/vamp_time}')
# Out:
# Time taken: 0.046881914138793945 seconds
# speedup: 232.55358382350732

# %% [markdown]
# Then test a traced and jit compiled version:

# %%
# %%time
# tracing time
amplitude_jit = torch.jit.trace(amplitude, (xs[0], params))
# Out:
# CPU times: user 13.3 s, sys: 774 ms, total: 14.1 s
# Wall time: 14.1 s

# %%
# %%time
# jit time
mantissa, exponent = amplitude_jit(xs[0], params)
mantissa, exponent
# Out:
# CPU times: user 7.95 s, sys: 141 ms, total: 8.09 s
# Wall time: 8.41 s
# (tensor(-1., device='cuda:0'), tensor(4.4671, device='cuda:0'))

# %%
# %%timeit
# warmed up time
mantissa, exponent = amplitude_jit(xs[0], params)
# Out:
# 77 ms ± 6.47 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
