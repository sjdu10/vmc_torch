# %%
from matplotlib import pyplot as plt
import numpy as np

Lx, Ly = 8, 8
D, chi = 4, 16

timing_file = f'./{Lx}x{Ly}_D={D}_chi={chi}_timing_results_float32.npy'
data = np.load(timing_file, allow_pickle=True).item()
batch_sizes = data['batch_sizes']
GPU_times = data['GPU_times']
CPU_times = data['CPU_times']

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, GPU_times, marker='o', label='GPU Time (s)')
plt.plot(batch_sizes, CPU_times, marker='o', label='CPU Time (s)')
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Batch Size')
plt.ylabel('Wall Time (seconds)')
plt.title(f'GPU vs CPU Time for Batch Sizes (L={Lx}x{Ly}, D={D}, chi={chi}, dtype=float32)')
plt.legend()
plt.grid(True)

# %%
from matplotlib import pyplot as plt
import numpy as np

Lx, Ly = 8, 8
D, chi = 8, 8

timing_file = f'./{Lx}x{Ly}_D={D}_chi={chi}_timing_results_float32.npy'
data = np.load(timing_file, allow_pickle=True).item()
batch_sizes = data['batch_sizes']
GPU_times = data['GPU_times']
CPU_times = data['CPU_times']

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, GPU_times, marker='o', label='GPU Time (s)')
plt.plot(batch_sizes, CPU_times, marker='o', label='CPU Time (s)')
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Batch Size')
plt.ylabel('Wall Time (seconds)')
plt.title(f'GPU vs CPU Time for Batch Sizes (L={Lx}x{Ly}, D={D}, chi={chi}, dtype=float32)')
plt.legend()
plt.grid(True)

# %%
from matplotlib import pyplot as plt
import numpy as np

Lx, Ly = 8, 8
D, chi = 6, 6

timing_file = f'./{Lx}x{Ly}_D={D}_chi={chi}_timing_results_float32.npy'
data = np.load(timing_file, allow_pickle=True).item()
batch_sizes = data['batch_sizes']
GPU_times = data['GPU_times']
CPU_times = data['CPU_times']

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, GPU_times, marker='o', label='GPU Time (s)')
plt.plot(batch_sizes, CPU_times, marker='o', label='CPU Time (s)')
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Batch Size')
plt.ylabel('Wall Time (seconds)')
plt.title(f'GPU vs CPU Time for Batch Sizes (L={Lx}x{Ly}, D={D}, chi={chi}, dtype=float32)')
plt.legend()
plt.grid(True)

# %%
from matplotlib import pyplot as plt
import numpy as np

Lx, Ly = 8, 8
D, chi = 10, 10

timing_file = f'./{Lx}x{Ly}_D={D}_chi={chi}_timing_results_float64.npy'
data = np.load(timing_file, allow_pickle=True).item()
batch_sizes = data['batch_sizes']
GPU_times = data['GPU_times']
CPU_times = data['CPU_times']

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, GPU_times, marker='o', label='GPU Time (s)')
plt.plot(batch_sizes, CPU_times, marker='o', label='CPU Time (s)')
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Batch Size')
plt.ylabel('Wall Time (seconds)')
plt.title(f'GPU vs CPU Time for Batch Sizes (L={Lx}x{Ly}, D={D}, chi={chi}, dtype=float64)')
plt.legend()
plt.grid(True)

# %%
from matplotlib import pyplot as plt
import numpy as np

Lx, Ly = 8, 8
D, chi = 8, 8

timing_file = f'./{Lx}x{Ly}_D={D}_chi={chi}_timing_results_float64.npy'
data = np.load(timing_file, allow_pickle=True).item()
batch_sizes = data['batch_sizes']
GPU_times = data['GPU_times']
CPU_times = data['CPU_times']

plt.figure(figsize=(8, 6))
plt.plot(batch_sizes, GPU_times, marker='o', label='GPU Time (s)')
plt.plot(batch_sizes, CPU_times, marker='o', label='CPU Time (s)')
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel('Batch Size')
plt.ylabel('Wall Time (seconds)')
plt.title(f'GPU vs CPU Time for Batch Sizes (L={Lx}x{Ly}, D={D}, chi={chi}, dtype=float64)')
plt.legend()
plt.grid(True)
