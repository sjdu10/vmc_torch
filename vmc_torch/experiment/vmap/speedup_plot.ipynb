# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# 4x8 lattice, D=4, NN-fPEPS, Np=80192, Ns=128,

# seq (1 MPI worker (1 CPU core), B=1 Markov chain): 303s (MKL speedup not obvious) (mem cost ~ 0.5GB)
# vmap (1 MPI worker (1 CPU core), B=64 Markov chains): 28s
# vmap (1 MPI worker (2 CPU cores for MKL), B=64 Markov chains): 22s (MKL speedup gradient Jacobian calc) (mem cost ~ 7GB, grad mem cost ~ 3GB, depending on the batch size B)

# 8x8 lattice, D=4, chi=16, NN-fPEPS, Np=163776, Ns=128,
# seq (1 MPI worker (1 CPU core), B=1 Markov chain): 4860s (MKL speedup not obvious) (mem cost ~ 1GB)
# vmap (1 MPI worker (2 CPU cores for MKL), B=16 Markov chains): 890s (MKL speedup gradient Jacobian calc) (mem cost ~ 15GB,  depending on the batch size B)
