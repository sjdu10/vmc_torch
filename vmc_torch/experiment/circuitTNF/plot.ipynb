# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 2
chis = [2, 4, ]
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
for chi, plot_data in chi_tau_Es.items():
    taus, Es = plot_data
    # sort by taus
    sorted_indices = np.argsort(taus)
    taus = taus[sorted_indices]
    Es = Es[sorted_indices]
    ax.plot(taus, Es, marker='o', label=rf'$\chi$={chi}')
ax.axhline(y=exact_E, color='r', linestyle='--', label='Exact GS E')
ax.axhline(y=SU_E, color='g', linestyle='--', label=rf'TEBD-MPS (D={D}) E')
ax.set_xlabel(r'$\tau$')
ax.set_ylabel('Energy')
ax.set_title(f'Circuit TNF Variational Energy (L={L}, D={D}, circuit depth={depth})')
#legend at upper right
ax.legend(loc='right')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 4
chis = [2, 4, 6, 8]
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots()
for chi, plot_data in chi_tau_Es.items():
    try:
        taus, Es = plot_data
        # sort by taus
        sorted_indices = np.argsort(taus)
        taus = taus[sorted_indices]
        Es = Es[sorted_indices]
        ax.plot(taus, Es, marker='o', label=rf'$\chi$={chi}')
    except ValueError:
        continue
ax.axhline(y=exact_E, color='r', linestyle='--', label='Exact GS E')
ax.axhline(y=SU_E, color='g', linestyle='--', label='TEBD E')
ax.set_xlabel(r'$\tau$')
ax.set_ylabel('Energy')
ax.set_title(f'Circuit TNF Variational Energy (L={L}, D={D}, circuit depth={depth})')
ax.legend()
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 6
chis = [2, 4, 6, 8]
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots()
for chi, plot_data in chi_tau_Es.items():
    try:
        taus, Es = plot_data
        # sort by taus
        sorted_indices = np.argsort(taus)
        taus = taus[sorted_indices]
        Es = Es[sorted_indices]
        ax.plot(taus, Es, marker='o', label=rf'$\chi$={chi}')
    except ValueError:
        continue
ax.axhline(y=exact_E, color='r', linestyle='--', label='Exact GS E')
ax.axhline(y=SU_E, color='g', linestyle='--', label='TEBD E')
ax.set_xlabel(r'$\tau$')
ax.set_ylabel('Energy')
ax.set_title(f'Circuit TNF Variational Energy (L={L}, D={D}, circuit depth={depth})')
ax.legend()
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 6
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 6
chis = [2, 4, 6]
chi_symbol = {2: 'o', 4: 's', 6: '^'}
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
for chi, plot_data in chi_tau_Es.items():
    try:
        taus, Es = plot_data
        # sort by taus
        sorted_indices = np.argsort(taus)
        taus = taus[sorted_indices]
        Es = Es[sorted_indices]
        ax[0].plot(taus, Es, label=rf'$\chi$={chi}, circuit depth={depth}', marker=chi_symbol[chi], markersize=6)

        # rel err
        rel_errs = np.abs((Es - exact_E) / exact_E)
        ax[1].plot(taus, rel_errs,  label=rf'$\chi$={chi}, circuit depth={depth}', marker=chi_symbol[chi], markersize=6)
          
    except ValueError:
        continue
ax[0].axhline(y=exact_E, color='r', linestyle='--', label='Exact GS')
ax[0].axhline(y=SU_E, color='g', linestyle='--', label=f'TEBD-MPS D={D}')
ax[0].set_xlabel(r'$\tau$')
ax[0].set_ylabel('Energy')
ax[0].set_title(f'Energy')
ax[0].legend()

ax[1].axhline(y=abs((SU_E - exact_E)/exact_E), color='g', linestyle='--', label=f'TEBD-MPS D={D}')
ax[1].set_yscale('log')
ax[1].set_xlabel(r'$\tau$')
ax[1].set_ylabel('Relative Error') 
ax[1].set_title(f'Relative Energy Error')
ax[1].legend()
plt.suptitle(f'Circuit TNF Variational Energy (L={L}, TEBD-MPS D={D})')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.254848653353348

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
from_which = 'yboth'
direction = 'spatial' if from_which[0]=='y' else 'inverse'
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r')) if from_which=='yboth' else json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results_{from_which}.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 10
chis = [2, 4, 6, 8]
chi_symbol = {2: 'o', 4: 's', 6: '^', 8: 'D'}
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
for chi, plot_data in chi_tau_Es.items():
    try:
        taus, Es = plot_data
        # sort by taus
        sorted_indices = np.argsort(taus)
        taus = taus[sorted_indices]
        Es = Es[sorted_indices]
        ax[0].plot(taus, Es, label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=6)

        # rel err
        rel_errs = np.abs((Es - exact_E) / exact_E)
        ax[1].plot(taus, rel_errs,  label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=6)
          
    except ValueError:
        continue

ax[0].axhline(y=SU_E, color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[0].axhline(y=exact_E, color='black', linestyle='-', label='Exact GS')
ax[0].set_xlabel(r'Trotter step $\tau$')
ax[0].set_ylabel('Energy')
ax[0].set_title(f'Energy')
ax[0].legend()

ax[1].axhline(y=abs((SU_E - exact_E)/exact_E), color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[1].set_yscale('log')
ax[1].set_xlabel(r'Trotter step $\tau$')
ax[1].set_ylabel('Relative Error') 
ax[1].set_title(f'Relative Energy Error')
ax[1].legend()
plt.suptitle(f'Circuit TNF Variational Energy (L={L}, TEBD-MPS D={D})')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
from_which = 'xmax'
direction = 'spatial' if from_which[0]=='y' else 'inverse'
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r')) if from_which=='yboth' else json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results_{from_which}.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 10
chis = [2, 4, 6, 8]
chi_symbol = {2: 'o', 4: 's', 6: '^', 8: 'D'}
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
for chi, plot_data in chi_tau_Es.items():
    try:
        taus, Es = plot_data
        # sort by taus
        sorted_indices = np.argsort(taus)
        taus = taus[sorted_indices]
        Es = Es[sorted_indices]
        ax[0].plot(taus, Es, label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=6)

        # rel err
        rel_errs = np.abs((Es - exact_E) / exact_E)
        ax[1].plot(taus, rel_errs,  label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=6)
          
    except ValueError:
        continue

ax[0].axhline(y=SU_E, color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[0].axhline(y=exact_E, color='black', linestyle='-', label='Exact GS')
ax[0].set_xlabel(r'Trotter step $\tau$')
ax[0].set_ylabel('Energy')
ax[0].set_title(f'Energy')
ax[0].legend()

ax[1].axhline(y=abs((SU_E - exact_E)/exact_E), color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[1].set_yscale('log')
ax[1].set_xlabel(r'Trotter step $\tau$')
ax[1].set_ylabel('Relative Error') 
ax[1].set_title(f'Relative Energy Error')
ax[1].legend()
plt.suptitle(f'Circuit TNF Variational Energy (L={L}, TEBD-MPS D={D})')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
from_which = 'xmax'
direction = 'spatial' if from_which[0]=='y' else 'inverse'
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r')) if from_which=='yboth' else json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results_{from_which}.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depth = 2
chis = [2, 4, 6, 8]
chi_symbol = {2: 'o', 4: 's', 6: '^', 8: 'D'}
chi_tau_Es = {chi: [] for chi in chis}
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')
for depth_tau_chi, Es in data_dict.items():
    d, tau, chi = depth_tau_chi
    if d == depth and chi in chis:
        chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

for chi, values in chi_tau_Es.items():
    chi_tau_Es[chi] = np.array(values).transpose()

# print(chi_tau_Es)
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
for chi, plot_data in chi_tau_Es.items():
    try:
        taus, Es = plot_data
        # sort by taus
        sorted_indices = np.argsort(taus)
        taus = taus[sorted_indices]
        Es = Es[sorted_indices]
        ax[0].plot(taus, Es, label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=6)

        # rel err
        rel_errs = np.abs((Es - exact_E) / exact_E)
        ax[1].plot(taus, rel_errs,  label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=6)
          
    except ValueError:
        continue

ax[0].axhline(y=SU_E, color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[0].axhline(y=exact_E, color='black', linestyle='-', label='Exact GS')
ax[0].set_xlabel(r'Trotter step $\tau$')
ax[0].set_ylabel('Energy')
ax[0].set_title(f'Energy')
ax[0].legend()

ax[1].axhline(y=abs((SU_E - exact_E)/exact_E), color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[1].set_yscale('log')
ax[1].set_xlabel(r'Trotter step $\tau$')
ax[1].set_ylabel('Relative Error') 
ax[1].set_title(f'Relative Energy Error')
ax[1].legend()
plt.suptitle(f'Circuit TNF Variational Energy (L={L}, TEBD-MPS D={D})')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
from_which = 'xmax'
direction = 'spatial' if from_which[0]=='y' else 'inverse'
# read json data
data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r')) if from_which=='yboth' else json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results_{from_which}.json', 'r'))

data_dict = {}

for name, Es in data.items():
    parts = name.split('_')
    depth = int(parts[2].split('=')[1])
    tau = float(parts[3].split('=')[1])
    max_bond = int(parts[4].split('=')[1])
    data_dict[(depth, tau, max_bond)] = Es

depths = [4,  10]
chis = [2, 4, 6]
exact_E = data_dict.values().__iter__().__next__()[2]
print(f'Exact ground state energy: {exact_E}')
SU_E = data_dict.values().__iter__().__next__()[1]
print(f'SU state energy: {SU_E}')

fig, ax = plt.subplots(1, 2, figsize=(20, 6))
chi_symbol = {2: 'o', 4: 's', 6: '^'}
chi_colors = {2: 'tab:blue', 4: 'tab:green', 6: 'tab:orange', 8: 'tab:red'}
depth_linestyles = {4: '--', 6: '-', 10: '-'}

for depth in depths:
    chi_tau_Es = {chi: [] for chi in chis}
    for depth_tau_chi, Es in data_dict.items():
        d, tau, chi = depth_tau_chi
        if d == depth and chi in chis:
            chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

    for chi, values in chi_tau_Es.items():
        chi_tau_Es[chi] = np.array(values).transpose()

    # print(chi_tau_Es)
    for chi, plot_data in chi_tau_Es.items():
        try:
            taus, Es = plot_data
            # sort by taus
            sorted_indices = np.argsort(taus)
            taus = taus[sorted_indices]
            Es = Es[sorted_indices]
            ax[0].plot(taus, Es, marker=chi_symbol[chi], label=rf'depth={depth}, $\chi$={chi}', linestyle=depth_linestyles[depth], color=chi_colors[chi], markersize=6)

            # rel err
            rel_errs = np.abs((Es - exact_E) / exact_E)
            ax[1].plot(taus, rel_errs, marker=chi_symbol[chi], label=rf'depth={depth}, $\chi$={chi}', linestyle=depth_linestyles[depth], color=chi_colors[chi], markersize=6)
            
        except ValueError:
            continue

ax[0].axhline(y=SU_E, color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[0].axhline(y=exact_E, color='k', linestyle='-', label='Exact GS')
ax[0].set_xlabel(r'Trotter step $\tau$')
ax[0].set_ylabel('Energy')
ax[0].set_title(f'Energy')
ax[0].legend()

ax[1].axhline(y=abs((SU_E - exact_E)/exact_E), color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[1].set_yscale('log')
ax[1].set_xlabel(r'Trotter step $\tau$')
ax[1].set_ylabel('Relative Error') 
ax[1].set_title(f'Relative Energy Error')
ax[1].legend()
plt.suptitle(rf'Imaginary Time Evolution Circuit TNF (L={L}, TEBD-MPS D={D}) for 1D Heisenberg spin chain (J=1)')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435

# %%
from matplotlib import pyplot as plt
import numpy as np
import json

L = 10
D = 4
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
for from_which in ['yboth', 'xmax']:
    # from_which = 'xmax'
    direction = 'spatial' if from_which[0]=='y' else 'inverse'
    # read json data
    data = json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results.json', 'r')) if from_which=='yboth' else json.load(open(f'./data/circuitTNF_heis_L{L}_D{D}_exact_sampling_results_{from_which}.json', 'r'))

    data_dict = {}

    for name, Es in data.items():
        parts = name.split('_')
        depth = int(parts[2].split('=')[1])
        tau = float(parts[3].split('=')[1])
        max_bond = int(parts[4].split('=')[1])
        data_dict[(depth, tau, max_bond)] = Es

    depth = 10
    chis = [2, 4, 6, 8]
    chi_symbol = {2: 'o', 4: 's', 6: '^', 8: 'D'}
    chi_colors = {2: 'tab:blue', 4: 'tab:green', 6: 'tab:orange', 8: 'tab:red'}
    direction_linestyles = {'spatial': '--', 'inverse': '-'}
    chi_tau_Es = {chi: [] for chi in chis}
    exact_E = data_dict.values().__iter__().__next__()[2]
    print(f'Exact ground state energy: {exact_E}')
    SU_E = data_dict.values().__iter__().__next__()[1]
    print(f'SU state energy: {SU_E}')
    for depth_tau_chi, Es in data_dict.items():
        d, tau, chi = depth_tau_chi
        if d == depth and chi in chis:
            chi_tau_Es[chi].append([tau, Es[0]])  # (tau, variational energy)

    for chi, values in chi_tau_Es.items():
        chi_tau_Es[chi] = np.array(values).transpose()

    # print(chi_tau_Es)

    for chi, plot_data in chi_tau_Es.items():
        try:
            taus, Es = plot_data
            # sort by taus
            sorted_indices = np.argsort(taus)
            taus = taus[sorted_indices]
            Es = Es[sorted_indices]
            ax[0].plot(taus, Es, label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=4, linestyle=direction_linestyles[direction], color=chi_colors[chi])

            # rel err
            rel_errs = np.abs((Es - exact_E) / exact_E)
            ax[1].plot(taus, rel_errs,  label=rf'circuit depth={depth}, $\chi$={chi}, {direction}', marker=chi_symbol[chi], markersize=4, linestyle=direction_linestyles[direction], color=chi_colors[chi])
            
        except ValueError:
            continue

ax[0].axhline(y=SU_E, color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[0].axhline(y=exact_E, color='black', linestyle='-', label='Exact GS')
ax[0].set_xlabel(r'Trotter step $\tau$')
ax[0].set_ylabel('Energy')
ax[0].set_title('Energy')
ax[0].legend()

ax[1].axhline(y=abs((SU_E - exact_E)/exact_E), color='b', linestyle='--', label=f'TEBD-MPS D={D}')
ax[1].set_yscale('log')
ax[1].set_xlabel(r'Trotter step $\tau$')
ax[1].set_ylabel('Relative Error') 
ax[1].set_title('Relative Energy Error')
ax[1].legend()
plt.suptitle(rf'Imaginary Time Evolution Circuit TNF (L={L}, TEBD-MPS D={D}) for 1D Heisenberg spin chain (J=1)')
plt.show()
# Out:
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435
# Exact ground state energy: -4.258035207282876
# SU state energy: -4.251935815622435
